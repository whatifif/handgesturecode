# %%
# Code repo
# https://github.com/whatifif/handgesturecode

# %%
import cv2
import numpy as np
import copy
import math
from appscript import app
import uuid
import os
import test64x64 as ML

# Environment:
# OS    : Mac OS High Siera
# python: 2.7.13
# opencv: 3.3.0

# Values to be initialised
Inited = False
frameW = None # frame width
frameH = None # frame height
marginX = 10 # margin between region
marginY = 10
gapX = 2 # margin between buttons
gapY = 2

# parameters
cap_region_x_end=0.5 # start point/total width
cap_region_y_end=0.8  # end point/total heighty
capStartX = 0 # keyboard region start x
capStartY = 0 # keyboard region start y
capEndX = None # keyboard region end x
capEndY = None # keyboard region end y


# buttons for capture 1
btnsX = None # btns start x 
btnsY = None # btns start y
btnsW = 600 # btns width
btnsH = 120 # btns height
bW = btnsW / 10  # btn width
bH = btnsH / 3  # btn height
bColor = (0, 255, 255) 
bThick = 2
bTitles = [
            ['lc', 'lo', 'lq', 'lw', 'le', 'l1', 'l2', 'l3', 'l4', 'l5' ],
            ['mc', 'mo', 'mq', 'mw', 'me', 'm1', 'm2', 'm3', 'm4', 'm5' ],
            ['rc', 'ro', 'rq', 'rw', 're', 'r1', 'r2', 'r3', 'r4', 'r5' ]
          ]
btns = [[(bW * j, bH * i, bTitles[i][j] ) for j in range(10)] for i in range(3)] 

# buttons for capture 2
btns2X = None # btns2 start x
btns2Y = None # btns2 start y
btns2W = 300 # btns2 width
btns2H = 120 # btns2 height
bW2 = btns2W / 5  # btn width
bH2 = btns2H / 2  # btn height
bTitles2 = [
            ['vc', 'vo', 'vq', 'vw', 've'],
            ['v1', 'v2', 'v3', 'v4', 'v5']
           ]
btns2 = [[(bW2 * j, bH2 * i, bTitles2[i][j] ) for j in range(5)] for i in range(2)] 

# Mouse Mode
MouseMode = False
mouse_region_x_begin = 0.7
mouse_region_y_end = 0.8
capStartX2 = None # mouse region start x
capStartY2 = 0 # mouse region start y
capEndX2 = None # mouse region end x
capEndY2 = None # mouse region end y

# GUI Mode
GUIMode = False
GUIInited = False

# Demo Mode
DemoMode = False

# variables for getSerialNumber
uid = str(uuid.uuid4())[:8]
inited = False
currentNum = 0
def getSerialNumber(serialPrefix = 'a', startNum = 0, endNum = 90000):
    global uid, inited, currentNum
    
    if not inited:
        currentNum = startNum
        inited = True
    else:
        currentNum += 1
        
    if currentNum > endNum:
        print ("!!! Exceeding Maximum Number !!!")
    
    return serialPrefix + '_' + uid + '_' + str(currentNum)
    
    
def printThreshold(thr):
    print("! Changed threshold to "+str(thr))


# GUI mode to capture a hand
ix, iy = -1, -1
currentClass = None
detectedClass = None
currentClass2 = None
detectedClass2 = None
imgClass = None
redColor = (0,0,255)

def handleClick(event,x,y,flags,param):
    global ix, iy, GUIMode
    
    if GUIMode and event == cv2.EVENT_LBUTTONDOWN:
        ix,iy = x,y
        detectBtn(ix, iy)

def detectBtn(ix, iy):
    global btnsX, btnsY, btnsW, btnsH, btns, btns2X, btns2Y, btns2W, btns2H, btns2
    global currentClass, detectedClass, currentClass2, detectedClass2
    
    if ((btnsX < ix) and (ix < btnsX + btnsW) and (btnsY < iy) and (iy < btnsY + btnsH)):
        nX = (ix - btnsX) // bW
        nY = (iy - btnsY) // bH
        currentClass = detectedClass = btns[nY][nX][2]
    
    elif MouseMode and ( btns2X < ix) and (ix < btns2X + btns2W) and (btns2Y < iy) and (iy < btns2Y + btns2H):
        nX = (ix - btns2X) // bW2
        nY = (iy - btns2Y) // bH2
        currentClass2 = detectedClass2 = btns2[nY][nX][2] 
    
def drawBtns(frame, btns, btnsX, btnsY, bW, bH, Class):
    numRows = len(btns)
    numCols = len(btns[0])
    
    for i in range(numRows):
        for j in range(numCols):
            drawBtn(frame, btns[i][j], btnsX, btnsY, bW, bH, Class)
            
def drawBtn(frame, btn, btnsX, btnsY, bW, bH, Class):
    global bColor, bThick, currentClass2, btns2X, btns2Y, bW2, bH2, redColor, gapX, gapY

    startPoint = (btnsX + btn[0] + gapX, btnsY + btn[1] + gapY)
    endPoint = (btnsX + btn[0] + bW - gapX, btnsY + btn[1] + bH - gapY)
    bTitle = btn[2]

    if Class == bTitle:
        color = redColor
    else:
        color = bColor

    cv2.rectangle(frame, startPoint, endPoint, color, bThick)
    cv2.putText(frame, bTitle, (startPoint[0]+8, startPoint[1]+32), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA)

# file path for cropped image
outDirPath = os.path.join('fdata', 'pic')
csvFilePath = os.path.join('fdata', 'fdata.csv')
csvFile = None

# margin for cropped image
margin = 10             
def getCrop(x, y, w, h, margin, img):
    # make a crop a square to prevent a shape destortion 
    if w > h: 
        delta = int((w-h)/2)

        y1 = y - delta - margin
        if y1 < 0: y1 = y

        y2 = y + h + delta + margin
        if y2 > img.shape[0]: y2 = y + h

        x1 = x - margin
        if x1 < 0: x1 = x

        x2 = x + w + margin
        if x2 > img.shape[1]: x2 = x + w

        crop = img[y1 : y2, x1 : x2]
    else:
        delta = int((h-w)/2)

        y1 = y - margin
        if y1 < 0: y1 = y

        y2 = y + h + margin
        if y2 > img.shape[0]: y2 = y + h

        x1 = x - delta - margin
        if x1 < 0: x1 = x

        x2 = x + w + delta + margin
        if x2 > img.shape[1]: x2 = x + w

        crop = img[y1 : y2, x1 : x2]
    return crop

def saveCrop(crop, imgClass):
    global outDirPath
    
    # make a crop a 200x200 pixel
    f_im = cv2.resize(crop,(200, 200), interpolation=cv2.INTER_CUBIC)

    # save into image file
    fileName = getSerialNumber('a', 0, 90000) + '_' + imgClass + '.jpg'
    out_path = os.path.join(outDirPath, fileName)
    cv2.imwrite(out_path, f_im)
    print out_path
    
    return fileName

def saveCsv(fileName, imgClass):
    global csvFilePath
    
    # save into csv file
    csvFile = open(csvFilePath, 'a') # to append a data to an existing csv file
    csvFile.write(fileName + ', ' + imgClass + '\r\n')
    csvFile.close()
    
def initParams(frame):
    global cap_region_x_end, cap_region_y_end, capStartX, capStartY, capEndX, capEndY
    global MouseMode, mouse_region_x_begin, mouse_region_y_end, capStartX2, capStartY2, capEndX2, capEndY2
    global frameW, frameH, btnsX, btnsY, btns2X, btns2Y, marginX, marginY
    
    frameW = frame.shape[1]
    frameH = frame.shape[0]
    capStartX = 0
    capStartY = 0
    capEndX = int(cap_region_x_end * frameW)
    capEndY = int(cap_region_y_end * frameH)
    capStartX2 = int(mouse_region_x_begin * frameW)
    capStartY2 = 0
    capEndX2 = frameW
    capEndY2 = int(mouse_region_y_end * frameH)
    
    btnsX = marginX
    btnsY = capEndY + marginY
    btns2X = capStartX2 + marginX
    btns2Y = frameH - btns2H - marginY
    
# track hand by skin color
skin_ycrcb_mint = np.array((0, 133, 77))
skin_ycrcb_maxt = np.array((255, 173, 127))

def trackHand(img):
    global skin_ycrcb_mint, skin_ycrcb_maxt
    
    im_ycrcb = cv2.cvtColor(img, cv2.COLOR_BGR2YCR_CB)
    skin_ycrcb = cv2.inRange(im_ycrcb, skin_ycrcb_mint, skin_ycrcb_maxt)    
    _, contours, _ = cv2.findContours(skin_ycrcb, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    ## get the coutours
    length = len(contours)
    maxArea = -1
    res = None
    if length > 0:
        for i in range(length):  # find the biggest contour (according to area)
            temp = contours[i]
            area = cv2.contourArea(temp)
            if area > maxArea:
                maxArea = area
                ci = i

        # draw the bounding rect
        res = contours[ci]
    return res

def drawGuide(frame, btnsX, btnsY, btnsW, marginX):
    cv2.putText(frame,"d: Demo mode", 
                (btnsX + btnsW + marginX, btnsY + 25), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                1,(0,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,"g: GUI mode", 
                (btnsX + btnsW + marginX, btnsY + 55), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                1,(0,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,"m: Mouse mode.", 
                (btnsX + btnsW + marginX, btnsY + 85), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                1,(0,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,"esc: quit", 
                (btnsX + btnsW + marginX, btnsY + 115),  
                cv2.FONT_HERSHEY_SIMPLEX, 
                1,(0,255,255),2,cv2.LINE_AA) 

# Camera
camera = cv2.VideoCapture(0)
camera.set(10,200)

cv2.namedWindow('main')
cv2.setMouseCallback('main', handleClick)

# main loop
prevClass = None

while camera.isOpened():
    ret, frame = camera.read()
    threshold = cv2.getTrackbarPos('trh1', 'trackbar')
    frame = cv2.bilateralFilter(frame, 5, 50, 100)  # smoothing filter
    frame = cv2.flip(frame, 1)  # flip the frame horizontally
    
    # init
    if not Inited:
        initParams(frame)
        Inited = True

    # keyboard region
    cv2.rectangle(frame, (capStartX, capStartY), (capEndX, capEndY), (255, 0, 0), 2)
    
    # mouse region
    if MouseMode:
        cv2.rectangle(frame, (capStartX2, capStartY2), (capEndX2, capEndY2), (255, 0, 0), 2)
        
    if GUIMode:
        if not GUIInited:
            if not os.path.exists(outDirPath):
                os.makedirs(outDirPath)
            GUIInited = True
            
        drawBtns(frame, btns, btnsX, btnsY, bW, bH, currentClass)
        
        if MouseMode:
            drawBtns(frame, btns2, btns2X, btns2Y, bW2, bH2, currentClass2)
        
    #  Main operation
    if True:
        img = frame[capStartY : capEndY, capStartX : capEndX]  # clip the ROI
        img = copy.deepcopy(img)
        res = trackHand(img)
        (x,y,w,h) = cv2.boundingRect(res)
        cv2.rectangle(frame, 
                      (capStartX + x - margin, y - margin), 
                      (capStartX + x + w + margin, y + h + margin), 
                      (0, 255, 255), 2)    
        
        # mouse
        if MouseMode:
            img2 = frame[capStartY2 : capEndY2, capStartX2: capEndX2]  # clip the ROI
            img2 = copy.deepcopy(img2)
            res2 = trackHand(img2)
            (x2,y2,w2,h2) = cv2.boundingRect(res2)
            cv2.rectangle(frame, 
                          (capStartX2 + x2 - margin, y2 - margin), 
                          (capStartX2 + x2 + w2 + margin, y2 + h2 + margin), 
                          (255, 0, 255), 2)
            
            #Find moments of the largest contour
            moments2 = cv2.moments(res2)

            #Central mass of first order moments
            if moments2['m00']!=0:
                cx2 = int(moments2['m10']/moments2['m00']) # cx = M10/M00
                cy2 = int(moments2['m01']/moments2['m00']) # cy = M01/M00
                centerMass2=(int(mouse_region_x_begin * frame.shape[1]) + cx2,cy2)    

                #Draw center mass
                cv2.circle(frame,centerMass2,5,[100,0,255],2)

        drawGuide(frame, btnsX, btnsY, btnsW, marginX)
           
        cv2.imshow('main', frame)

    # Keyboard OP
    k = cv2.waitKey(10)
    if k == 27:  # press ESC to exit
        if csvFile and (not csvFile.closed):
            csvFile.close()
        break
        
    elif k == ord('g'): # GUI mode to capture a hand
        if not GUIMode: 
            GUIMode = True
            print '!!! GUI Mode on !!!'
        else:
            GUIMode = False
            print '!!! GUI Mode off !!!'
    
    elif k == ord('m'): # Mouse mode to capture a hand
        if not MouseMode: 
            MouseMode = True
            print '!!! Mouse Mode on !!!'
        else:
            MouseMode = False
            print '!!! Mouse Mode off !!!'
            
    elif k == ord('d'): # Mouse mode to capture a hand
        if not DemoMode: 
            DemoMode = True
            print '!!! Demo Mode on !!!'
        else:
            DemoMode = False
            print '!!! Demo Mode off !!!'
            
    elif GUIMode:
        if detectedClass:
            imgClass = detectedClass
            X = x
            Y = y
            W = w
            H = h
            Img = img
            
        elif detectedClass2:
            imgClass = detectedClass2 
            X = x2
            Y = y2
            W = w2
            H = h2
            Img = img2
            
        if imgClass:
            # get a crop
            crop = getCrop(X, Y, W, H, margin, Img)

            # make a crop a 200x200 pixel
            fileName = saveCrop(crop, imgClass)

            # save into csv file
            saveCsv(fileName, imgClass)

            # restore the initial state
            imgClass = detectedClass = detectedClass2 = None
            
    elif DemoMode:
        X = x
        Y = y
        W = w
        H = h
        Img = img
        crop = getCrop(X, Y, W, H, margin, Img)
        predictedClass = ML.predict(crop)
        
        if predictedClass != prevClass:
            prevClass = predictedClass
            print predictedClass
            
        
camera.release()
cv2.destroyAllWindows()
# Out:
# !!! Demo Mode on !!!
# probability=0.517108, class= lq
# probability=0.185994, class= rq
# probability=0.074479, class= mw
# probability=0.056596, class=vq
# probability=0.042515, class= re
#  lq
# probability=0.409134, class=vc
# probability=0.364801, class=vq
# probability=0.106212, class=v3
# probability=0.078056, class= rc
# probability=0.023243, class= lq
# vc
# probability=0.391190, class=vq
# probability=0.387972, class=vc
# probability=0.103243, class=v3
# probability=0.077422, class= rc
# probability=0.022013, class= lq
# vq
# probability=0.383733, class=vc
# probability=0.358545, class=vq
# probability=0.115050, class=v3
# probability=0.085994, class= rc
# probability=0.035301, class= lq
# vc
# probability=0.519096, class=vq
# probability=0.324698, class=vc
# probability=0.074669, class=v3
# probability=0.039319, class= rc
# probability=0.027184, class= lq
# vq
# probability=0.703211, class=vq
# probability=0.153631, class=vc
# probability=0.061484, class=v3
# probability=0.048710, class= lq
# probability=0.013673, class= rc
# probability=0.828694, class=vc
# probability=0.056885, class= rc
# probability=0.041739, class= lq
# probability=0.033171, class=vq
# probability=0.024608, class=v3
# vc
# probability=0.650991, class= lq
# probability=0.141980, class= rq
# probability=0.050066, class= mw
# probability=0.047307, class=v4
# probability=0.033552, class= re
#  lq
# probability=0.919881, class=vc
# probability=0.029486, class= rc
# probability=0.024475, class= lq
# probability=0.010084, class=vq
# probability=0.005696, class=v3
# vc
# probability=0.703031, class= lq
# probability=0.125041, class= rq
# probability=0.044816, class=v4
# probability=0.037349, class= mw
# probability=0.032335, class= re
#  lq
# probability=0.703047, class= lq
# probability=0.128908, class= rq
# probability=0.066769, class=v4
# probability=0.023031, class= re
# probability=0.022913, class= mw
# probability=0.521348, class=vc
# probability=0.259149, class=vq
# probability=0.077951, class= lq
# probability=0.072423, class= rc
# probability=0.040081, class=v3
# vc
# probability=0.903272, class=vc
# probability=0.032909, class= lq
# probability=0.027832, class= rc
# probability=0.015785, class=vq
# probability=0.008922, class=v3
# probability=0.662993, class= lq
# probability=0.201567, class= rq
# probability=0.052966, class=v4
# probability=0.015166, class= mw
# probability=0.014368, class= re
#  lq
# probability=0.643713, class= lq
# probability=0.205401, class= rq
# probability=0.070845, class=v4
# probability=0.019141, class=v3
# probability=0.012361, class= mw
# probability=0.623087, class= lq
# probability=0.220424, class= rq
# probability=0.076037, class=v4
# probability=0.019792, class=v3
# probability=0.010877, class= mw
# probability=0.637798, class= lq
# probability=0.222745, class= rq
# probability=0.064722, class=v4
# probability=0.016047, class=v3
# probability=0.011231, class= mw
# probability=0.653785, class= lq
# probability=0.205562, class= rq
# probability=0.060492, class=v4
# probability=0.018728, class=v3
# probability=0.012247, class= mw
# probability=0.631662, class= lq
# probability=0.246926, class= rq
# probability=0.038573, class=v4
# probability=0.022786, class=v3
# probability=0.009142, class= mw
# probability=0.632729, class= lq
# probability=0.252550, class= rq
# probability=0.030398, class=v4
# probability=0.021369, class=v3
# probability=0.010141, class=vq
# probability=0.632461, class= lq
# probability=0.244876, class= rq
# probability=0.028522, class=v4
# probability=0.025886, class=v3
# probability=0.010713, class=vq
# probability=0.666263, class= lq
# probability=0.197496, class= rq
# probability=0.036829, class=v3
# probability=0.034092, class=v4
# probability=0.011141, class=vq
# probability=0.642107, class= lq
# probability=0.243031, class= rq
# probability=0.034364, class=v3
# probability=0.026852, class=v4
# probability=0.008007, class=vq
# probability=0.704477, class= lq
# probability=0.179892, class= rq
# probability=0.034571, class=v3
# probability=0.021940, class=v4
# probability=0.014842, class=vq
# probability=0.673781, class= lq
# probability=0.202450, class= rq
# probability=0.035236, class=v3
# probability=0.024824, class=v4
# probability=0.013629, class=vq
# probability=0.645066, class= lq
# probability=0.215036, class= rq
# probability=0.044554, class=v3
# probability=0.027947, class=v4
# probability=0.014881, class=vq
# probability=0.619389, class= lq
# probability=0.236625, class= rq
# probability=0.044631, class=v3
# probability=0.022237, class=v4
# probability=0.021932, class=vq
# probability=0.651084, class= lq
# probability=0.212085, class= rq
# probability=0.037328, class=v3
# probability=0.026190, class=vq
# probability=0.017794, class=v4
# probability=0.653368, class= lq
# probability=0.201842, class= rq
# probability=0.043958, class=v3
# probability=0.026494, class=vq
# probability=0.018604, class=v4
# probability=0.601075, class= lq
# probability=0.244641, class= rq
# probability=0.052256, class=v3
# probability=0.023154, class=vq
# probability=0.021321, class=v4
# probability=0.675808, class= lq
# probability=0.170475, class= rq
# probability=0.047670, class=v3
# probability=0.030967, class=vq
# probability=0.020145, class=v4
# probability=0.613318, class= lq
# probability=0.254854, class= rq
# probability=0.041924, class=v3
# probability=0.026762, class=v4
# probability=0.013798, class=vq
# probability=0.662258, class= lq
# probability=0.195685, class= rq
# probability=0.046466, class=v3
# probability=0.023833, class=v4
# probability=0.020760, class=vq
# probability=0.664785, class= lq
# probability=0.218598, class= rq
# probability=0.036988, class=v3
# probability=0.018451, class=v4
# probability=0.016407, class=vq
# probability=0.658122, class= lq
# probability=0.210910, class= rq
# probability=0.048387, class=v3
# probability=0.021774, class=v4
# probability=0.015915, class=vc
# probability=0.671680, class= lq
# probability=0.203716, class= rq
# probability=0.046159, class=v3
# probability=0.021896, class=v4
# probability=0.013874, class=vq
# probability=0.694421, class= lq
# probability=0.181409, class= rq
# probability=0.043485, class=v3
# probability=0.018942, class=vq
# probability=0.018870, class=v4
# probability=0.672236, class= lq
# probability=0.197210, class= rq
# probability=0.050444, class=v3
# probability=0.022015, class=v4
# probability=0.014979, class=vq
# probability=0.641214, class= lq
# probability=0.231496, class= rq
# probability=0.041813, class=v3
# probability=0.028848, class=v4
# probability=0.012375, class=vq
# probability=0.659928, class= lq
# probability=0.204790, class= rq
# probability=0.035114, class=v3
# probability=0.033640, class=v4
# probability=0.013644, class=vq
# probability=0.668410, class= lq
# probability=0.205187, class= rq
# probability=0.032605, class=v3
# probability=0.030518, class=v4
# probability=0.012885, class=vq
# probability=0.650563, class= lq
# probability=0.228969, class= rq
# probability=0.040222, class=v4
# probability=0.028107, class=v3
# probability=0.018996, class=vc
# probability=0.524417, class= lq
# probability=0.311829, class= rq
# probability=0.072905, class=vc
# probability=0.038743, class=v4
# probability=0.025570, class=v3
# probability=0.530047, class=vc
# probability=0.291919, class= rq
# probability=0.113185, class= lq
# probability=0.025838, class=v3
# probability=0.016431, class=v4
# vc
# probability=0.958245, class=vc
# probability=0.013347, class= rc
# probability=0.008266, class=v3
# probability=0.006873, class= lq
# probability=0.003925, class= rq
# probability=0.942160, class=vc
# probability=0.015991, class= rc
# probability=0.012489, class= lq
# probability=0.010824, class=v3
# probability=0.004181, class= rq
# probability=0.872570, class=vc
# probability=0.038603, class= lq
# probability=0.033172, class= rq
# probability=0.021153, class=v3
# probability=0.012127, class= rc
# probability=0.838698, class=vc
# probability=0.054630, class= rq
# probability=0.052045, class= lq
# probability=0.021236, class=v3
# probability=0.009731, class= rc
# probability=0.869525, class=vc
# probability=0.063058, class= rq
# probability=0.033178, class= lq
# probability=0.012170, class=v3
# probability=0.006139, class=v4
# probability=0.836949, class=vc
# probability=0.070762, class= rq
# probability=0.047005, class= lq
# probability=0.018076, class=v3
# probability=0.007444, class=v4
# probability=0.819290, class=vc
# probability=0.086192, class= rq
# probability=0.051554, class= lq
# probability=0.016044, class=v3
# probability=0.009925, class=v4
# probability=0.254914, class=v1
# probability=0.211464, class= lc
# probability=0.191382, class=vc
# probability=0.146590, class=v4
# probability=0.077389, class=v3
# v1
# probability=0.587720, class=ve
# probability=0.150432, class=v1
# probability=0.110824, class=v3
# probability=0.028483, class=vo
# probability=0.017611, class= lo
# ve
# probability=0.640734, class=ve
# probability=0.150343, class=v1
# probability=0.097338, class=vo
# probability=0.031769, class=v3
# probability=0.022356, class=v4
# probability=0.846789, class=ve
# probability=0.041930, class=v1
# probability=0.020224, class=v3
# probability=0.013918, class=vq
# probability=0.012746, class=vo
# probability=0.840756, class=ve
# probability=0.032899, class=v1
# probability=0.027353, class=vq
# probability=0.022393, class=v3
# probability=0.012423, class= lq
# probability=0.843222, class=ve
# probability=0.031162, class=v1
# probability=0.029642, class=vq
# probability=0.023056, class=v3
# probability=0.011690, class= lq
# probability=0.838765, class=ve
# probability=0.039706, class=vq
# probability=0.024461, class=v1
# probability=0.023274, class=v3
# probability=0.012109, class=vw
# probability=0.824933, class=ve
# probability=0.054608, class=vq
# probability=0.024597, class=v3
# probability=0.018656, class=v1
# probability=0.016363, class= lq
# probability=0.849611, class=ve
# probability=0.049007, class=vq
# probability=0.019888, class=v3
# probability=0.019865, class=v1
# probability=0.014339, class=vw
# probability=0.848177, class=ve
# probability=0.045870, class=vq
# probability=0.022283, class=v3
# probability=0.021342, class=v1
# probability=0.012511, class=vw
# probability=0.843356, class=ve
# probability=0.051846, class=vq
# probability=0.025236, class=v3
# probability=0.019814, class=v1
# probability=0.012216, class=vw
# probability=0.860131, class=ve
# probability=0.048318, class=vq
# probability=0.020313, class=v3
# probability=0.019925, class=v1
# probability=0.012226, class=vw
# probability=0.884694, class=ve
# probability=0.037390, class=vq
# probability=0.020286, class=v1
# probability=0.017312, class=v3
# probability=0.011644, class=vw
# probability=0.893755, class=ve
# probability=0.034981, class=vq
# probability=0.018966, class=v1
# probability=0.016456, class=v3
# probability=0.010699, class=vw
# probability=0.910098, class=ve
# probability=0.025067, class=vq
# probability=0.021588, class=v1
# probability=0.011337, class=v3
# probability=0.010593, class=vw
# probability=0.907471, class=ve
# probability=0.026927, class=v1
# probability=0.020585, class=vq
# probability=0.011429, class=v3
# probability=0.009286, class=vw
# probability=0.908986, class=ve
# probability=0.036528, class=v1
# probability=0.013044, class=vq
# probability=0.010250, class=vo
# probability=0.009265, class=v3
# probability=0.892273, class=ve
# probability=0.046869, class=v1
# probability=0.014559, class=vo
# probability=0.009106, class=vq
# probability=0.008461, class=v3
# probability=0.915854, class=ve
# probability=0.039361, class=v1
# probability=0.009069, class=vq
# probability=0.008720, class=vw
# probability=0.005673, class=v3
# probability=0.895407, class=ve
# probability=0.047881, class=v1
# probability=0.010245, class=vq
# probability=0.008239, class=vw
# probability=0.007141, class=vo
# probability=0.897452, class=ve
# probability=0.038555, class=v1
# probability=0.015360, class=vq
# probability=0.011188, class=vw
# probability=0.007544, class=v3
# probability=0.902254, class=ve
# probability=0.026052, class=v1
# probability=0.022462, class=vq
# probability=0.013911, class=vw
# probability=0.008306, class=v3
# probability=0.896151, class=ve
# probability=0.026166, class=v1
# probability=0.024431, class=vq
# probability=0.014193, class=vw
# probability=0.008450, class=v3
# probability=0.901439, class=ve
# probability=0.023572, class=v1
# probability=0.023272, class=vq
# probability=0.015207, class=vw
# probability=0.006482, class=v3
# probability=0.903420, class=ve
# probability=0.025016, class=vq
# probability=0.021124, class=v1
# probability=0.015947, class=vw
# probability=0.006048, class=v3
# probability=0.894666, class=ve
# probability=0.030317, class=v1
# probability=0.021024, class=vq
# probability=0.014032, class=vw
# probability=0.006713, class=v3
# probability=0.910313, class=ve
# probability=0.025525, class=v1
# probability=0.018232, class=vq
# probability=0.011114, class=vw
# probability=0.007108, class=v3
# probability=0.895852, class=ve
# probability=0.030594, class=v1
# probability=0.019479, class=vq
# probability=0.011632, class=vw
# probability=0.008384, class=v3
# probability=0.878395, class=ve
# probability=0.031778, class=v1
# probability=0.022211, class=vq
# probability=0.013344, class=vw
# probability=0.007880, class=v3
# probability=0.873195, class=ve
# probability=0.030662, class=v1
# probability=0.025438, class=vq
# probability=0.014109, class=vw
# probability=0.008176, class= le
# probability=0.852617, class=ve
# probability=0.043196, class=v1
# probability=0.020947, class=vq
# probability=0.014639, class=vw
# probability=0.009770, class= le
# probability=0.840023, class=ve
# probability=0.052782, class=v1
# probability=0.020012, class=vq
# probability=0.014171, class=vw
# probability=0.010642, class=vo
# probability=0.830094, class=ve
# probability=0.060044, class=v1
# probability=0.020261, class=vq
# probability=0.014521, class=vw
# probability=0.012554, class=vo
# probability=0.837216, class=ve
# probability=0.063022, class=v1
# probability=0.016306, class=vq
# probability=0.013044, class=vw
# probability=0.012514, class=vo
# probability=0.832435, class=ve
# probability=0.060295, class=v1
# probability=0.017641, class=vq
# probability=0.015124, class=vo
# probability=0.013233, class=vw
# probability=0.809127, class=ve
# probability=0.063194, class=v1
# probability=0.021049, class=vq
# probability=0.018174, class=vo
# probability=0.014896, class=vw
# probability=0.818319, class=ve
# probability=0.069619, class=v1
# probability=0.021120, class=vo
# probability=0.015069, class=vq
# probability=0.014046, class=vw
# probability=0.809410, class=ve
# probability=0.063257, class=v1
# probability=0.024026, class=vo
# probability=0.015859, class=vq
# probability=0.013864, class=vw
# probability=0.816784, class=ve
# probability=0.061382, class=v1
# probability=0.023096, class=vo
# probability=0.016688, class=vq
# probability=0.015515, class=vw
# probability=0.777517, class=ve
# probability=0.086835, class=v1
# probability=0.032897, class=vo
# probability=0.015992, class=vw
# probability=0.013134, class= le
# probability=0.914352, class=ve
# probability=0.041559, class=v1
# probability=0.010057, class=vo
# probability=0.006867, class=vw
# probability=0.005722, class=vq
# probability=0.912644, class=ve
# probability=0.040445, class=v1
# probability=0.009298, class=vo
# probability=0.007887, class=vw
# probability=0.007129, class=vq
# probability=0.901455, class=ve
# probability=0.040512, class=v1
# probability=0.010065, class=vo
# probability=0.009849, class=vw
# probability=0.008986, class=vq
# probability=0.901277, class=ve
# probability=0.033363, class=v1
# probability=0.012120, class=vq
# probability=0.011706, class=vw
# probability=0.009479, class=vo
# probability=0.910911, class=ve
# probability=0.032748, class=v1
# probability=0.010097, class=vw
# probability=0.009537, class=vq
# probability=0.008581, class=vo
# probability=0.900963, class=ve
# probability=0.032516, class=v1
# probability=0.011261, class=vo
# probability=0.011194, class=vw
# probability=0.010847, class=vq
# probability=0.902193, class=ve
# probability=0.035446, class=v1
# probability=0.011665, class=vo
# probability=0.011074, class=vw
# probability=0.009074, class=vq
# probability=0.894981, class=ve
# probability=0.038675, class=v1
# probability=0.014020, class=vo
# probability=0.011108, class=vw
# probability=0.009274, class=vq
# probability=0.888319, class=ve
# probability=0.041003, class=v1
# probability=0.016500, class=vo
# probability=0.010866, class=vw
# probability=0.009658, class=vq
# probability=0.880692, class=ve
# probability=0.046886, class=v1
# probability=0.016575, class=vo
# probability=0.011556, class=vw
# probability=0.009137, class=vq
# probability=0.883701, class=ve
# probability=0.044447, class=v1
# probability=0.017188, class=vo
# probability=0.011584, class=vw
# probability=0.008944, class=vq
# probability=0.882786, class=ve
# probability=0.051463, class=v1
# probability=0.019372, class=vo
# probability=0.010080, class=vw
# probability=0.006924, class=v4
# probability=0.880830, class=ve
# probability=0.054963, class=v1
# probability=0.018461, class=vo
# probability=0.010047, class=vw
# probability=0.006381, class=v4
# probability=0.925102, class=ve
# probability=0.038936, class=v1
# probability=0.009422, class=vo
# probability=0.006881, class=vw
# probability=0.003979, class=v4
# probability=0.919424, class=ve
# probability=0.038476, class=v1
# probability=0.010295, class=vo
# probability=0.008125, class=vw
# probability=0.004763, class=vq
# probability=0.932995, class=ve
# probability=0.031136, class=v1
# probability=0.007647, class=vw
# probability=0.007010, class=vo
# probability=0.005165, class=vq
# probability=0.919750, class=ve
# probability=0.035365, class=v1
# probability=0.009221, class=vo
# probability=0.008912, class=vw
# probability=0.006127, class=vq
# probability=0.926237, class=ve
# probability=0.030988, class=v1
# probability=0.008553, class=vw
# probability=0.008390, class=vo
# probability=0.005977, class=vq
# probability=0.927184, class=ve
# probability=0.032266, class=v1
# probability=0.008759, class=vo
# probability=0.007833, class=vw
# probability=0.005566, class=vq
# probability=0.927843, class=ve
# probability=0.025873, class=v1
# probability=0.009464, class=vw
# probability=0.007711, class=vo
# probability=0.007353, class=vq
# probability=0.926048, class=ve
# probability=0.026762, class=v1
# probability=0.009253, class=vo
# probability=0.008349, class=vw
# probability=0.007364, class=vq
# probability=0.928040, class=ve
# probability=0.025330, class=v1
# probability=0.008843, class=vo
# probability=0.008430, class=vw
# probability=0.007605, class=vq
# probability=0.922457, class=ve
# probability=0.026538, class=v1
# probability=0.010795, class=vo
# probability=0.008435, class=vw
# probability=0.007854, class=vq
# probability=0.926660, class=ve
# probability=0.024899, class=v1
# probability=0.010069, class=vo
# probability=0.007958, class=vq
# probability=0.007904, class=vw
# probability=0.922129, class=ve
# probability=0.026882, class=v1
# probability=0.011063, class=vo
# probability=0.007904, class=vw
# probability=0.007626, class=vq
# probability=0.920440, class=ve
# probability=0.027666, class=v1
# probability=0.011226, class=vo
# probability=0.008293, class=vw
# probability=0.008001, class=vq
# probability=0.925575, class=ve
# probability=0.024907, class=v1
# probability=0.010451, class=vo
# probability=0.008863, class=vq
# probability=0.008445, class=vw
# probability=0.928135, class=ve
# probability=0.021874, class=v1
# probability=0.009373, class=vw
# probability=0.009133, class=vq
# probability=0.008258, class=vo
# probability=0.927764, class=ve
# probability=0.022589, class=v1
# probability=0.009152, class=vq
# probability=0.009148, class=vw
# probability=0.008810, class=vo
# probability=0.921533, class=ve
# probability=0.028011, class=v1
# probability=0.011123, class=vo
# probability=0.008637, class=vw
# probability=0.007655, class=vq
# probability=0.925371, class=ve
# probability=0.026001, class=v1
# probability=0.009482, class=vo
# probability=0.009066, class=vw
# probability=0.008042, class=vq
# probability=0.912281, class=ve
# probability=0.028491, class=v1
# probability=0.013894, class=vo
# probability=0.009110, class=vw
# probability=0.008985, class=vq
# probability=0.915759, class=ve
# probability=0.025973, class=v1
# probability=0.012889, class=vo
# probability=0.009765, class=vq
# probability=0.009462, class=vw
# probability=0.922061, class=ve
# probability=0.026735, class=v1
# probability=0.012183, class=vo
# probability=0.008496, class=vw
# probability=0.007787, class=vq
# probability=0.924423, class=ve
# probability=0.024884, class=v1
# probability=0.012606, class=vo
# probability=0.007897, class=vq
# probability=0.007890, class=vw
# probability=0.927499, class=ve
# probability=0.023332, class=v1
# probability=0.012580, class=vo
# probability=0.007678, class=vq
# probability=0.007197, class=vw
# probability=0.923587, class=ve
# probability=0.022981, class=v1
# probability=0.012331, class=vo
# probability=0.009051, class=vq
# probability=0.008105, class=vw
# probability=0.929582, class=ve
# probability=0.021148, class=v1
# probability=0.011300, class=vo
# probability=0.008035, class=vq
# probability=0.007486, class=vw
# probability=0.922916, class=ve
# probability=0.022961, class=v1
# probability=0.013549, class=vo
# probability=0.008776, class=vq
# probability=0.007570, class=vw
# probability=0.929371, class=ve
# probability=0.021819, class=v1
# probability=0.012054, class=vo
# probability=0.008260, class=vq
# probability=0.006896, class=vw
# probability=0.918912, class=ve
# probability=0.023768, class=v1
# probability=0.014600, class=vo
# probability=0.009670, class=vq
# probability=0.007681, class=vw
# probability=0.920445, class=ve
# probability=0.022540, class=v1
# probability=0.015815, class=vo
# probability=0.008860, class=vq
# probability=0.007294, class=v4
# probability=0.929867, class=ve
# probability=0.020901, class=v1
# probability=0.015090, class=vo
# probability=0.007148, class=vq
# probability=0.006972, class=v4
# probability=0.928200, class=ve
# probability=0.018466, class=v1
# probability=0.016152, class=vo
# probability=0.008831, class=vq
# probability=0.006717, class=v4
# probability=0.926341, class=ve
# probability=0.023770, class=v1
# probability=0.019558, class=vo
# probability=0.007347, class=v4
# probability=0.005644, class=v3
# probability=0.921389, class=ve
# probability=0.022905, class=v1
# probability=0.022016, class=vo
# probability=0.008622, class=v4
# probability=0.006053, class=vq
# probability=0.923857, class=ve
# probability=0.022606, class=vo
# probability=0.021379, class=v1
# probability=0.008772, class=v4
# probability=0.005909, class=v3
# probability=0.922676, class=ve
# probability=0.022460, class=v1
# probability=0.021542, class=vo
# probability=0.008016, class=v4
# probability=0.006929, class=vq
# probability=0.937531, class=ve
# probability=0.019090, class=v1
# probability=0.016006, class=vo
# probability=0.006308, class=v4
# probability=0.005843, class=vq
# probability=0.942978, class=ve
# probability=0.018136, class=v1
# probability=0.014316, class=vo
# probability=0.005800, class=v4
# probability=0.005355, class=vq
# probability=0.940625, class=ve
# probability=0.016471, class=v1
# probability=0.015802, class=vo
# probability=0.006328, class=vq
# probability=0.005898, class=v4
# probability=0.940886, class=ve
# probability=0.017103, class=v1
# probability=0.016387, class=vo
# probability=0.006737, class=v4
# probability=0.005138, class=v3
# probability=0.938170, class=ve
# probability=0.018522, class=v1
# probability=0.016783, class=vo
# probability=0.006061, class=v4
# probability=0.005748, class=vq
# probability=0.951393, class=ve
# probability=0.014063, class=v1
# probability=0.013031, class=vo
# probability=0.005427, class=v4
# probability=0.004527, class=vq
# probability=0.946860, class=ve
# probability=0.015348, class=v1
# probability=0.014019, class=vo
# probability=0.005751, class=vq
# probability=0.005049, class=v4
# probability=0.947563, class=ve
# probability=0.016025, class=v1
# probability=0.013970, class=vo
# probability=0.005306, class=vq
# probability=0.005168, class=v4
# probability=0.945843, class=ve
# probability=0.017214, class=v1
# probability=0.015102, class=vo
# probability=0.004991, class=vq
# probability=0.004873, class=v3
# probability=0.944428, class=ve
# probability=0.014430, class=vo
# probability=0.013516, class=v1
# probability=0.007667, class=vq
# probability=0.005667, class=v3
# probability=0.942599, class=ve
# probability=0.017740, class=vo
# probability=0.016255, class=v1
# probability=0.005392, class=vq
# probability=0.005256, class=v4
# probability=0.588246, class=ve
# probability=0.216817, class=vo
# probability=0.142292, class=v1
# probability=0.037510, class=v4
# probability=0.008273, class=v3
# probability=0.944384, class=ve
# probability=0.017946, class=vo
# probability=0.013360, class=v1
# probability=0.006152, class=vq
# probability=0.005341, class=v4
# probability=0.945070, class=ve
# probability=0.016636, class=vo
# probability=0.013376, class=v1
# probability=0.006084, class=vq
# probability=0.005880, class=v4
# probability=0.942382, class=ve
# probability=0.017602, class=vo
# probability=0.013980, class=v1
# probability=0.007164, class=v4
# probability=0.005848, class=vq
# probability=0.931894, class=ve
# probability=0.023082, class=vo
# probability=0.018132, class=v1
# probability=0.008146, class=v4
# probability=0.005618, class=v3
# probability=0.939990, class=ve
# probability=0.021250, class=vo
# probability=0.016479, class=v1
# probability=0.007310, class=v4
# probability=0.005347, class=v3
# probability=0.927387, class=ve
# probability=0.027464, class=vo
# probability=0.018984, class=v1
# probability=0.008941, class=v4
# probability=0.006720, class=v3
# probability=0.933880, class=ve
# probability=0.022405, class=vo
# probability=0.018371, class=v1
# probability=0.008082, class=v4
# probability=0.005540, class=v3
# probability=0.931517, class=ve
# probability=0.025444, class=vo
# probability=0.016643, class=v1
# probability=0.009830, class=v4
# probability=0.006190, class=v3
# probability=0.941600, class=ve
# probability=0.020594, class=vo
# probability=0.015323, class=v1
# probability=0.007494, class=v4
# probability=0.005207, class=v3
# probability=0.945853, class=ve
# probability=0.018671, class=vo
# probability=0.014954, class=v1
# probability=0.007051, class=v4
# probability=0.004973, class=v3
# probability=0.926083, class=ve
# probability=0.027399, class=vo
# probability=0.021306, class=v1
# probability=0.009324, class=v4
# probability=0.006328, class=v3
# probability=0.929343, class=ve
# probability=0.027922, class=vo
# probability=0.019498, class=v1
# probability=0.009054, class=v4
# probability=0.005126, class=v3
# probability=0.934854, class=ve
# probability=0.024331, class=vo
# probability=0.014715, class=v1
# probability=0.009058, class=v4
# probability=0.005978, class=v3
# probability=0.922129, class=ve
# probability=0.031418, class=vo
# probability=0.020848, class=v1
# probability=0.009260, class=v4
# probability=0.005681, class=v3
# probability=0.917255, class=ve
# probability=0.034912, class=vo
# probability=0.016730, class=v1
# probability=0.011714, class=v4
# probability=0.007210, class=v3
# probability=0.908097, class=ve
# probability=0.042469, class=vo
# probability=0.020625, class=v1
# probability=0.011442, class=v4
# probability=0.007167, class=v3
# probability=0.928897, class=ve
# probability=0.028406, class=vo
# probability=0.016030, class=v1
# probability=0.008440, class=v4
# probability=0.007325, class=v3
# probability=0.938633, class=ve
# probability=0.023646, class=vo
# probability=0.012385, class=v1
# probability=0.007524, class=v3
# probability=0.006080, class=vq
# probability=0.930712, class=ve
# probability=0.027083, class=vo
# probability=0.014181, class=v1
# probability=0.008727, class=v4
# probability=0.007325, class=v3
# probability=0.927885, class=ve
# probability=0.029768, class=vo
# probability=0.015985, class=v1
# probability=0.009462, class=v4
# probability=0.006750, class=v3
# probability=0.913114, class=ve
# probability=0.037786, class=vo
# probability=0.018951, class=v1
# probability=0.012360, class=v4
# probability=0.006645, class=v3
# probability=0.921896, class=ve
# probability=0.033052, class=vo
# probability=0.019973, class=v1
# probability=0.010135, class=v4
# probability=0.006555, class=v3
# probability=0.906662, class=ve
# probability=0.040188, class=vo
# probability=0.024778, class=v1
# probability=0.013746, class=v4
# probability=0.006076, class=v3
# probability=0.919201, class=ve
# probability=0.031314, class=vo
# probability=0.023804, class=v1
# probability=0.012239, class=v4
# probability=0.005301, class=v3
# probability=0.922695, class=ve
# probability=0.028302, class=v1
# probability=0.024504, class=vo
# probability=0.011597, class=v4
# probability=0.004517, class=v3
# probability=0.914833, class=ve
# probability=0.029647, class=v1
# probability=0.025958, class=vo
# probability=0.014754, class=v4
# probability=0.005831, class=v3
# probability=0.920943, class=ve
# probability=0.029478, class=v1
# probability=0.024704, class=vo
# probability=0.011646, class=v4
# probability=0.004151, class=v3
# probability=0.917426, class=ve
# probability=0.034784, class=v1
# probability=0.024509, class=vo
# probability=0.010664, class=v4
# probability=0.003910, class=v3
# probability=0.895907, class=ve
# probability=0.044345, class=v1
# probability=0.033902, class=vo
# probability=0.012144, class=v4
# probability=0.004639, class=v3
# probability=0.886074, class=ve
# probability=0.044727, class=v1
# probability=0.036797, class=vo
# probability=0.013954, class=v4
# probability=0.005611, class=v3
# probability=0.886248, class=ve
# probability=0.051317, class=v1
# probability=0.036351, class=vo
# probability=0.014023, class=v4
# probability=0.004938, class=v3
# probability=0.885894, class=ve
# probability=0.051612, class=v1
# probability=0.037767, class=vo
# probability=0.013568, class=v4
# probability=0.004811, class=v3
# probability=0.892773, class=ve
# probability=0.049478, class=v1
# probability=0.033993, class=vo
# probability=0.013081, class=v4
# probability=0.004833, class=v3
# probability=0.899203, class=ve
# probability=0.042580, class=v1
# probability=0.034309, class=vo
# probability=0.013183, class=v4
# probability=0.004964, class=v3
# probability=0.893175, class=ve
# probability=0.051940, class=v1
# probability=0.033588, class=vo
# probability=0.012021, class=v4
# probability=0.004784, class=v3
# probability=0.906630, class=ve
# probability=0.036649, class=v1
# probability=0.031135, class=vo
# probability=0.014503, class=v4
# probability=0.006146, class=v3
# probability=0.916998, class=ve
# probability=0.028485, class=v1
# probability=0.028338, class=vo
# probability=0.015003, class=v4
# probability=0.005692, class=v3
# probability=0.900399, class=ve
# probability=0.037913, class=vo
# probability=0.030473, class=v1
# probability=0.018451, class=v4
# probability=0.006864, class=v3
# probability=0.986512, class=v1
# probability=0.009864, class=vo
# probability=0.001385, class=ve
# probability=0.000864, class= lo
# probability=0.000361, class= l4
# v1
# probability=0.899911, class=ve
# probability=0.044449, class=vo
# probability=0.026571, class=v1
# probability=0.016726, class=v4
# probability=0.006794, class=v3
# ve
# probability=0.896908, class=ve
# probability=0.044490, class=vo
# probability=0.031044, class=v1
# probability=0.016300, class=v4
# probability=0.006722, class=v3
# probability=0.888717, class=ve
# probability=0.050479, class=vo
# probability=0.033193, class=v1
# probability=0.015916, class=v4
# probability=0.006877, class=v3
# probability=0.890461, class=ve
# probability=0.050033, class=vo
# probability=0.031039, class=v1
# probability=0.016300, class=v4
# probability=0.007171, class=v3
# probability=0.915815, class=ve
# probability=0.035943, class=vo
# probability=0.022894, class=v1
# probability=0.012923, class=v4
# probability=0.007175, class=v3
# probability=0.935558, class=ve
# probability=0.024719, class=vo
# probability=0.015521, class=v1
# probability=0.010166, class=v4
# probability=0.007920, class=v3
# probability=0.931082, class=ve
# probability=0.028733, class=vo
# probability=0.016402, class=v1
# probability=0.010931, class=v4
# probability=0.007558, class=v3
# probability=0.932132, class=ve
# probability=0.027822, class=vo
# probability=0.016484, class=v1
# probability=0.010394, class=v4
# probability=0.007790, class=v3
# probability=0.938166, class=ve
# probability=0.024404, class=vo
# probability=0.014883, class=v1
# probability=0.010306, class=v4
# probability=0.007326, class=v3
# probability=0.694444, class=ve
# probability=0.138993, class=vo
# probability=0.132104, class=v1
# probability=0.025202, class=v4
# probability=0.006708, class=v3
# probability=0.946142, class=ve
# probability=0.019008, class=vo
# probability=0.011339, class=v1
# probability=0.008996, class=v4
# probability=0.008418, class=v3
# probability=0.952262, class=ve
# probability=0.016600, class=vo
# probability=0.009804, class=v1
# probability=0.007684, class=v4
# probability=0.007193, class=v3
# probability=0.942747, class=ve
# probability=0.021195, class=vo
# probability=0.011711, class=v1
# probability=0.009641, class=v4
# probability=0.008431, class=v3
# probability=0.933902, class=ve
# probability=0.026028, class=vo
# probability=0.013449, class=v1
# probability=0.011467, class=v4
# probability=0.008940, class=v3
# probability=0.934206, class=ve
# probability=0.026465, class=vo
# probability=0.013128, class=v1
# probability=0.010004, class=v4
# probability=0.009469, class=v3
# probability=0.935739, class=ve
# probability=0.026863, class=vo
# probability=0.014460, class=v1
# probability=0.008894, class=v4
# probability=0.008006, class=v3
# probability=0.943061, class=ve
# probability=0.023497, class=vo
# probability=0.011819, class=v1
# probability=0.007817, class=v3
# probability=0.007567, class=v4
# probability=0.946575, class=ve
# probability=0.019435, class=vo
# probability=0.010480, class=v1
# probability=0.008655, class=v3
# probability=0.008292, class=v4
# probability=0.956478, class=ve
# probability=0.015090, class=vo
# probability=0.009405, class=v1
# probability=0.006753, class=v3
# probability=0.006229, class=v4
# probability=0.943496, class=ve
# probability=0.021885, class=vo
# probability=0.009921, class=v1
# probability=0.009004, class=v3
# probability=0.008880, class=v4
# probability=0.936661, class=ve
# probability=0.025397, class=vo
# probability=0.014641, class=v1
# probability=0.009269, class=v4
# probability=0.008878, class=v3
# probability=0.934134, class=ve
# probability=0.026763, class=vo
# probability=0.015986, class=v1
# probability=0.010097, class=v4
# probability=0.007975, class=v3
# probability=0.948973, class=ve
# probability=0.018662, class=vo
# probability=0.009895, class=v1
# probability=0.008569, class=v4
# probability=0.007765, class=v3
# probability=0.928823, class=ve
# probability=0.030246, class=vo
# probability=0.015371, class=v1
# probability=0.010869, class=v4
# probability=0.009445, class=v3
# probability=0.941459, class=ve
# probability=0.022818, class=vo
# probability=0.011326, class=v1
# probability=0.009643, class=v4
# probability=0.009306, class=v3
# probability=0.945590, class=ve
# probability=0.022427, class=vo
# probability=0.010707, class=v1
# probability=0.008357, class=v3
# probability=0.007503, class=v4
# probability=0.947888, class=ve
# probability=0.020896, class=vo
# probability=0.010879, class=v1
# probability=0.007657, class=v3
# probability=0.007251, class=v4
# probability=0.946376, class=ve
# probability=0.021548, class=vo
# probability=0.010498, class=v1
# probability=0.008507, class=v3
# probability=0.007315, class=v4
# probability=0.378124, class= l4
# probability=0.134552, class= le
# probability=0.126767, class= m2
# probability=0.070969, class= lw
# probability=0.047738, class= r5
#  l4
# probability=0.950861, class=ve
# probability=0.017159, class=vo
# probability=0.009417, class=v3
# probability=0.008580, class=v1
# probability=0.007545, class=v4
# ve
# probability=0.950632, class=ve
# probability=0.017505, class=vo
# probability=0.009636, class=v3
# probability=0.009519, class=v1
# probability=0.007359, class=v4
# probability=0.935712, class=ve
# probability=0.027462, class=vo
# probability=0.016290, class=v1
# probability=0.008894, class=v4
# probability=0.007398, class=v3
# probability=0.923987, class=ve
# probability=0.031940, class=vo
# probability=0.019238, class=v1
# probability=0.010985, class=v4
# probability=0.009418, class=v3
# probability=0.932941, class=ve
# probability=0.027553, class=vo
# probability=0.015568, class=v1
# probability=0.009938, class=v3
# probability=0.009245, class=v4
# probability=0.174121, class= mc
# probability=0.132845, class=vc
# probability=0.125509, class= m5
# probability=0.047777, class= m2
# probability=0.045011, class= m4
#  mc
# probability=0.933090, class=ve
# probability=0.026884, class=vo
# probability=0.014954, class=v1
# probability=0.010508, class=v4
# probability=0.009134, class=v3
# ve
# probability=0.913777, class=ve
# probability=0.037581, class=vo
# probability=0.020913, class=v1
# probability=0.013394, class=v4
# probability=0.009391, class=v3
# probability=0.929322, class=ve
# probability=0.030120, class=vo
# probability=0.017724, class=v1
# probability=0.011475, class=v4
# probability=0.007242, class=v3
# probability=0.939018, class=ve
# probability=0.023477, class=vo
# probability=0.016060, class=v1
# probability=0.010407, class=v4
# probability=0.007008, class=v3
# probability=0.920214, class=ve
# probability=0.031319, class=vo
# probability=0.026151, class=v1
# probability=0.011727, class=v4
# probability=0.007174, class=v3
# probability=0.899967, class=ve
# probability=0.040419, class=vo
# probability=0.034590, class=v1
# probability=0.014589, class=v4
# probability=0.007011, class=v3
# probability=0.896378, class=ve
# probability=0.040625, class=vo
# probability=0.038114, class=v1
# probability=0.014380, class=v4
# probability=0.007267, class=v3
# probability=0.916262, class=ve
# probability=0.030712, class=vo
# probability=0.027130, class=v1
# probability=0.014613, class=v4
# probability=0.007945, class=v3
# probability=0.917616, class=ve
# probability=0.030161, class=vo
# probability=0.027632, class=v1
# probability=0.013776, class=v4
# probability=0.007367, class=v3
# probability=0.917840, class=ve
# probability=0.028990, class=vo
# probability=0.028196, class=v1
# probability=0.013787, class=v4
# probability=0.007388, class=v3
# probability=0.907515, class=ve
# probability=0.034797, class=vo
# probability=0.031455, class=v1
# probability=0.015141, class=v4
# probability=0.007643, class=v3
# probability=0.878312, class=ve
# probability=0.046653, class=v1
# probability=0.043538, class=vo
# probability=0.020392, class=v4
# probability=0.007843, class=v3
# probability=0.881228, class=ve
# probability=0.051154, class=v1
# probability=0.041288, class=vo
# probability=0.016690, class=v4
# probability=0.006542, class=v3
# probability=0.885477, class=ve
# probability=0.046728, class=v1
# probability=0.039712, class=vo
# probability=0.018011, class=v4
# probability=0.006744, class=v3
# probability=0.908392, class=ve
# probability=0.033789, class=v1
# probability=0.033200, class=vo
# probability=0.013439, class=v4
# probability=0.007616, class=v3
# probability=0.912436, class=ve
# probability=0.034019, class=vo
# probability=0.027862, class=v1
# probability=0.014240, class=v4
# probability=0.007828, class=v3
# probability=0.921612, class=ve
# probability=0.031862, class=vo
# probability=0.020010, class=v1
# probability=0.013460, class=v4
# probability=0.008847, class=v3
# probability=0.923260, class=ve
# probability=0.030363, class=vo
# probability=0.022109, class=v1
# probability=0.011866, class=v4
# probability=0.008099, class=v3
# probability=0.915619, class=ve
# probability=0.033625, class=vo
# probability=0.025122, class=v1
# probability=0.012465, class=v4
# probability=0.008803, class=v3
# probability=0.930299, class=ve
# probability=0.027435, class=vo
# probability=0.018986, class=v1
# probability=0.010576, class=v4
# probability=0.008085, class=v3
# probability=0.924999, class=ve
# probability=0.029147, class=vo
# probability=0.017366, class=v1
# probability=0.012379, class=v4
# probability=0.010340, class=v3
# probability=0.920121, class=ve
# probability=0.031015, class=vo
# probability=0.018660, class=v1
# probability=0.012594, class=v4
# probability=0.011655, class=v3
# probability=0.918998, class=ve
# probability=0.032022, class=vo
# probability=0.019675, class=v1
# probability=0.014034, class=v4
# probability=0.010041, class=v3
# probability=0.917770, class=ve
# probability=0.034838, class=vo
# probability=0.018862, class=v1
# probability=0.012585, class=v4
# probability=0.011054, class=v3
# probability=0.919884, class=ve
# probability=0.033051, class=vo
# probability=0.017596, class=v1
# probability=0.012814, class=v4
# probability=0.011214, class=v3
# probability=0.932656, class=ve
# probability=0.024959, class=vo
# probability=0.012196, class=v1
# probability=0.011824, class=v3
# probability=0.010870, class=v4
# probability=0.903455, class=ve
# probability=0.043313, class=vo
# probability=0.021925, class=v1
# probability=0.014231, class=v4
# probability=0.011520, class=v3
# probability=0.931300, class=ve
# probability=0.025627, class=vo
# probability=0.013791, class=v1
# probability=0.012130, class=v3
# probability=0.010779, class=v4
# probability=0.929973, class=ve
# probability=0.027348, class=vo
# probability=0.014729, class=v1
# probability=0.011727, class=v4
# probability=0.010929, class=v3
# probability=0.904789, class=ve
# probability=0.040130, class=vo
# probability=0.018014, class=v1
# probability=0.016158, class=v4
# probability=0.013057, class=v3
# probability=0.896087, class=ve
# probability=0.043641, class=vo
# probability=0.018046, class=v4
# probability=0.017671, class=v1
# probability=0.014912, class=v3
# probability=0.899368, class=ve
# probability=0.040138, class=vo
# probability=0.017421, class=v4
# probability=0.016855, class=v3
# probability=0.016634, class=v1
# probability=0.899832, class=ve
# probability=0.037304, class=vo
# probability=0.017723, class=v1
# probability=0.017430, class=v4
# probability=0.015500, class=v3
# probability=0.887265, class=ve
# probability=0.043929, class=vo
# probability=0.020218, class=v4
# probability=0.019245, class=v1
# probability=0.017123, class=v3
# probability=0.892067, class=ve
# probability=0.040587, class=vo
# probability=0.019477, class=v4
# probability=0.018484, class=v1
# probability=0.017152, class=v3
# probability=0.909272, class=ve
# probability=0.033300, class=vo
# probability=0.015705, class=v1
# probability=0.015060, class=v3
# probability=0.014591, class=v4
# probability=0.902332, class=ve
# probability=0.036298, class=vo
# probability=0.017447, class=v3
# probability=0.016194, class=v4
# probability=0.015374, class=v1
# probability=0.908255, class=ve
# probability=0.034945, class=vo
# probability=0.016496, class=v1
# probability=0.015258, class=v4
# probability=0.013984, class=v3
# probability=0.905419, class=ve
# probability=0.034288, class=vo
# probability=0.019282, class=v1
# probability=0.015979, class=v3
# probability=0.015357, class=v4
# probability=0.892568, class=ve
# probability=0.041849, class=vo
# probability=0.019814, class=v1
# probability=0.018368, class=v4
# probability=0.017922, class=v3
# probability=0.902512, class=ve
# probability=0.035243, class=vo
# probability=0.017330, class=v1
# probability=0.016979, class=v4
# probability=0.016871, class=v3
# probability=0.901007, class=ve
# probability=0.035104, class=vo
# probability=0.018443, class=v1
# probability=0.017630, class=v3
# probability=0.017418, class=v4
# probability=0.903617, class=ve
# probability=0.035753, class=vo
# probability=0.017183, class=v3
# probability=0.016601, class=v1
# probability=0.016298, class=v4
# probability=0.893713, class=ve
# probability=0.043661, class=vo
# probability=0.018998, class=v1
# probability=0.018295, class=v4
# probability=0.015451, class=v3
# probability=0.905045, class=ve
# probability=0.032276, class=vo
# probability=0.018915, class=v3
# probability=0.017210, class=v4
# probability=0.016039, class=v1
# probability=0.905436, class=ve
# probability=0.034285, class=vo
# probability=0.017140, class=v1
# probability=0.016732, class=v4
# probability=0.016215, class=v3
# probability=0.908374, class=ve
# probability=0.034867, class=vo
# probability=0.017536, class=v1
# probability=0.014333, class=v4
# probability=0.012861, class=v3
# probability=0.890097, class=ve
# probability=0.045458, class=vo
# probability=0.022427, class=v1
# probability=0.017283, class=v4
# probability=0.013876, class=v3
# probability=0.920530, class=ve
# probability=0.028380, class=vo
# probability=0.015325, class=v1
# probability=0.012804, class=v4
# probability=0.011178, class=v3
# probability=0.899039, class=ve
# probability=0.038449, class=vo
# probability=0.018958, class=v1
# probability=0.017733, class=v4
# probability=0.009958, class=v3
# probability=0.911357, class=ve
# probability=0.035282, class=vo
# probability=0.015128, class=v1
# probability=0.012636, class=v4
# probability=0.010602, class=v3
# probability=0.900179, class=ve
# probability=0.026878, class=v3
# probability=0.025165, class=vo
# probability=0.015295, class=vq
# probability=0.015078, class=v4
# probability=0.492986, class=ve
# probability=0.321562, class=vq
# probability=0.083946, class= lq
# probability=0.034710, class=v3
# probability=0.023778, class=vw
# probability=0.595472, class=vw
# probability=0.186061, class=vq
# probability=0.180667, class=ve
# probability=0.015900, class= lq
# probability=0.011850, class= mw
# vw
# probability=0.554251, class=ve
# probability=0.418652, class=vw
# probability=0.015436, class=vq
# probability=0.004010, class= lw
# probability=0.001822, class= mw
# ve
# probability=0.423508, class=ve
# probability=0.098840, class=vw
# probability=0.071627, class=v1
# probability=0.065305, class= lw
# probability=0.065049, class= mw
# probability=0.398625, class=vw
# probability=0.351108, class=ve
# probability=0.052610, class= lw
# probability=0.040306, class= rw
# probability=0.032932, class=vq
# vw
# probability=0.446732, class=ve
# probability=0.130267, class=vw
# probability=0.050804, class=v1
# probability=0.048582, class=v4
# probability=0.042827, class= re
# ve
# probability=0.480740, class=ve
# probability=0.127541, class=vw
# probability=0.061118, class=v4
# probability=0.047657, class=v1
# probability=0.040123, class= re
# probability=0.499485, class=ve
# probability=0.121464, class=vw
# probability=0.054931, class=v1
# probability=0.051885, class=v4
# probability=0.043216, class= re
# probability=0.471344, class=ve
# probability=0.123313, class=vw
# probability=0.060712, class=v4
# probability=0.046129, class=v1
# probability=0.044229, class= re
# probability=0.497108, class=ve
# probability=0.121439, class=vw
# probability=0.047993, class= re
# probability=0.047064, class= lw
# probability=0.041394, class=v1
# probability=0.452012, class=ve
# probability=0.124055, class=vw
# probability=0.074367, class= lw
# probability=0.063055, class= re
# probability=0.044132, class= rw
# probability=0.245843, class=ve
# probability=0.208594, class= lw
# probability=0.127446, class=vw
# probability=0.102937, class= re
# probability=0.076060, class= le
# probability=0.209012, class= lw
# probability=0.207300, class=vq
# probability=0.160990, class=vw
# probability=0.118758, class= le
# probability=0.114771, class= re
#  lw
# probability=0.293106, class=vq
# probability=0.164768, class= re
# probability=0.159490, class= lw
# probability=0.097048, class=vw
# probability=0.078411, class= le
# vq
# probability=0.310772, class=vq
# probability=0.165226, class= lw
# probability=0.143618, class=vw
# probability=0.111686, class= re
# probability=0.080495, class= rw
# probability=0.349927, class=vq
# probability=0.146393, class=vw
# probability=0.140567, class= lw
# probability=0.097454, class= rw
# probability=0.089057, class= re
